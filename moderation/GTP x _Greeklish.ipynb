# %% [markdown]
# # Dependencies

# %%
# %%capture
# !pip install openai
# !pip install anthropic

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import openai
import anthropic
import time
import textwrap

openai.api_key = "api key to use te service"
# path to data
path = ''

# %% [markdown]
# # Preliminaries

# %%
def call_openai(system, query, model="gpt-3.5-turbo", max_tokens=100):
  start_time = time.time()
  completion = openai.ChatCompletion.create(
  model=model,
  messages=[
      {"role": "system", "content": system},
      {"role": "user", "content": query}
      ],
  temperature=0,
  max_tokens=max_tokens,
  )
  answer = completion.choices[0].message.content
  end_time = time.time()
  return answer, end_time-start_time

def call_anthropic(system, query, model="claude-v1.3", max_tokens=100):
  client = anthropic.Client(ANTHROPIC_API_KEY_TRIAL)
  start_time = time.time()
  for attempt in range(15):
    try:
      response = client.completion(
          prompt=f"{anthropic.HUMAN_PROMPT} {system}\n\n{query}{anthropic.AI_PROMPT}",
          stop_sequences = [anthropic.HUMAN_PROMPT],
          model=model,
          max_tokens_to_sample=max_tokens,
          temperature=0)
    except:
      print(f"Exception occurred! ({attempt+1})")
      time.sleep(0.35)
      continue
    else:
      break
  answer = response['completion']
  end_time = time.time()
  return answer, end_time-start_time

# %% [markdown]
# # Pipeline

# %% [markdown]
# Read and sample data

# %%
import random
random_seed = 1247

# read data and sample sentences for few-shot learning
# accepted
with open(path + 'greeklish_gazzetta_accepted.txt', "r", encoding="utf-8") as file:
  greeklish_accepted = []
  for line in file:
    if line[-1] == "\n" and line[:-1]:
        greeklish_accepted.append(line[:-1])

with open(path + 'greeklish_gazzetta_accepted.txt', "r", encoding="utf-8") as file:
  greek_accepted = []
  for line in file:
    if line[-1] == "\n" and line[:-1]:
        greek_accepted.append(line[:-1])
  # only use the translations from the first annotator
  greek_accepted = greek_accepted[:len(greeklish_accepted)]


# rejected
with open(path + 'greeklish_gazzetta_rejected.txt', "r", encoding="utf-8") as file:
  greeklish_rejected = []
  for line in file:
    if line[-1] == "\n" and line[:-1]:
        greeklish_rejected.append(line[:-1])

with open(path + 'greeklish_gazzetta_rejected.txt', "r", encoding="utf-8") as file:
  greek_rejected = []
  for line in file:
    if line[-1] == "\n" and line[:-1]:
        greek_rejected.append(line[:-1])
  # only use the translations from the first annotator
  greek_rejected = greek_rejected[:len(greeklish_rejected)]

random.seed(random_seed)
greeklish = random.sample(greeklish_accepted, 5)
random.seed(random_seed)
greeklish = random.sample(greeklish_rejected, 5)

random.seed(random_seed)
greek = random.sample(greek_accepted, 5)
random.seed(random_seed)
greek = random.sample(greek_rejected, 5)

# %% [markdown]
# ## Create "system"

# %% [markdown]
# Zero-shot version

# %%
# Prepare the prompt, or in the chatgpt terminology the "system"
#instruction = "Translate the following sentences from Greeklish to Greek. Do not use different words."
instruction_zero = "You are an expert in online content moderation. The following sentences are online user comments in Greeklish, which can either be accepted or rejected for posting by the moderator. For each sentence provided, classify as either 0 for \"rejected\" or 1 for \"accepted\". Here is an example: \n\n"
system = f"{instruction_zero}\n\n"

for i in range (len(greeklish)):
  system = f"{system}Sentence:\n{greeklish[i]}\n"
  cls = "1" if i<5 else "2"
  system = f"{system}Class:\n{cls}\n\n"

# print the entire prompt given to GPT4
print(system)

# %% [markdown]
# Few-shot version (greeklish translations)

# %%
# Prepare the prompt, or in the chatgpt terminology the "system"

# Create prompt
instruction_few = "You are an expert in online content moderation. The following sentences are online user comments in Greeklish, which can either be accepted or rejected for posting by the moderator, depending on their toxicity. For each sentence provided, classify as either 0 for \"rejected\" or 1 for \"accepted\". Here is an example: \n\n"
system = f"{instruction_few}\n\n"

for i in range (len(greeklish)):
  system = f"{system}Sentence:\n{greeklish[i]}\n"
  cls = "1" if i<5 else "2"
  system = f"{system}Class:\n{cls}\n\n"

"For every sentence provided, only return the number of the class (0 or 1). To help you better understand Greeklish, here are some examples of Greeklish sentences and their translations in Greek:"
system = f"{instruction_few}\n\n"

system = f"{instruction_few}\n\n"
for i in range (len(greeklish)):
  system = f"{system}Greeklish:\n{greeklish[i]}\n"
  system = f"{system}Greek:\n{greek[i]}\n\n"

# print the entire prompt given to GPT4
print(system)

# %% [markdown]
# ## Run queries

# %% [markdown]
# GPT-4

# %%
import time
import pandas as pd
# Multiple queries for running experiments with gpt-4
datasets = ["accepted","rejected"]
mode = "few"

for dataset in datasets:
  print("======Working on {} dataset======".format(dataset))

  # get correct dataset
  if dataset == "accepted":
    queries = []
  else:
    queries = []

  # call gpt4
  results_gpt4 = []
  for query in queries:
    print(textwrap.fill(query, initial_indent="Sentence:\t", subsequent_indent="\t"))
    res, t = call_openai(system, query, model="gpt-4")
    results_gpt4.append((query,res))
    print(textwrap.fill(res, initial_indent="gpt-4:\t", subsequent_indent="\t"))
    print(f"Generated answer in {t:.3f} seconds\n")

    # for flow control
    time.sleep(1)

  print("Saving results...")
  df = pd.DataFrame(results_gpt4, columns=["sentence", "class"])
  df['class'] = df['class'].astype(int)
  df.to_csv(path+ "gpt4_toxicity_{}_gazzetta_{}_.csv".format(mode, dataset), index=False)

  with open(path+ "gpt4_toxicity_{}_gazzetta_{}_.txt".format(mode, dataset), 'w', encoding="utf-8") as file:
        for line in results_gpt4:
            file.write(line)
            file.write("\n")
  time.sleep(2)
# Out:
# ======Working on accepted dataset======
# Sentence:	Roberto eisai super agori mou!!!
# gpt-4:	Class: 1
# Generated answer in 1.080 seconds
#
# Sentence:	Otan o Diamantidis sou epairne Eurwpaiko k se pigaine teliko
# 	Moundobasket den ta eleges auta tote....
# gpt-4:	Class: 1
# Generated answer in 0.909 seconds
#
# Sentence:	Alla eixes afisei ta opadika stin akri,panugirizes kai eixes
# 	parei fanela Ethnikis me to onoma Diamantidis pisw....
# gpt-4:	Class: 1
# Generated answer in 0.640 seconds
#
# Sentence:	Ela pes tin alitheia den einai kako....
# gpt-4:	Class: 1
# Generated answer in 1.423 seconds
#
# Sentence:	To xete kanei karamela oloi les k den epaixe pote Ethniki
# 	alla toso komplexikoi eiste....
# gpt-4:	Class: 0
# Generated answer in 0.574 seconds
#
# Sentence:	O spanoulis ti ekane me tin Ethniki??
# gpt-4:	Class: 1
# Generated answer in 0.581 seconds
#
# Sentence:	Xeiroteri thesi se Eurobasket den exoume parei pote....
# gpt-4:	Class: 1
# Generated answer in 1.029 seconds
#
# Sentence:	Megalwse o 3D den to xere na paizei mexri ta 40 Ethniki gia
# 	na min ton krazete oi gayroi....
# gpt-4:	Class: 1
# Generated answer in 0.905 seconds
#
# Sentence:	Gia ton papalouka gt den lete den tha mporouse na paixei
# 	akoma asxeta pou den paizei basket pia stin Ethniki mporei na
# 	voithisei akoma....
# gpt-4:	Class: 1
# Generated answer in 0.556 seconds
#
# Sentence:	Gazzeta perna to toso kopo ekana....
# gpt-4:	Class: 1
# Generated answer in 0.839 seconds
#
# Sentence:	AXAXAXAXAXAXAXAXA
# gpt-4:	Class: 1
# Generated answer in 0.767 seconds
#
# Sentence:	pame beroia
# gpt-4:	Class: 1
# Generated answer in 0.605 seconds
#
# Sentence:	TI?????????
# gpt-4:	Class: 1
# Generated answer in 0.875 seconds
#
# Sentence:	kurie mwralh sas parakalw gia to kalo tou podosfairou
# 	pagosmios apla paraiththeite gia na mhn pw kati pio sklhro kai m
# 	kanoun delete to keimeno
# gpt-4:	Class: 0
# Generated answer in 0.597 seconds
#
# Sentence:	einai kai sklirotraxilos, mas tairiazei ganti.
# gpt-4:	Class: 1
# Generated answer in 0.476 seconds
#
# Sentence:	paragouai ktl k oxi argentinobrazilero
# gpt-4:	Class: 1
# Generated answer in 1.491 seconds
#
# Sentence:	Omadara!!!
# gpt-4:	Class: 0
# Generated answer in 0.590 seconds
#
# Sentence:	Paixtarades oloi!!!!
# gpt-4:	Class: 1
# Generated answer in 0.488 seconds
#
# Sentence:	XAXAXAXAXAXAXAXAXAAXAXAXAXAXAXAXAXAXAXAAXAXA...
# gpt-4:	Class: 1
# Generated answer in 0.716 seconds
#
# Sentence:	Tha fas kala.......
# gpt-4:	Class: 1
# Generated answer in 0.490 seconds
#
# Sentence:	xaxa..xairomai poy se peirakse toso poly to sxolio.
# gpt-4:	Class: 1
# Generated answer in 0.507 seconds
#
# Sentence:	einai perisotero ellinas apo kati allous!!!
# gpt-4:	Class: 1
# Generated answer in 0.571 seconds
#
# Sentence:	gazzetta pernatw den vrizw!!!
# gpt-4:	Class: 1
# Generated answer in 0.769 seconds
#
# Sentence:	se 2 xronia superleague se 4 afanismos
# gpt-4:	Class: 1
# Generated answer in 0.773 seconds
#
# Sentence:	guestlist eisai to ligotero asteios agori mou eite to
# 	diabases eite oxi to kommati…
# gpt-4:	Class: 0
# Generated answer in 0.534 seconds
#
# Sentence:	Jimaras vgalate glwssa epeze h mish omada eiste pou8enades
# gpt-4:	Class: 0
# Generated answer in 0.579 seconds
#
# Sentence:	pws se lene telospantwn
# gpt-4:	Class: 1
# Generated answer in 0.601 seconds
#
# Sentence:	milaei o rwsos gia e3ygiansh kai ka8aro podosfairo kai
# 	peytoun mpouketa kai 3yliki sthn toumpa..
# gpt-4:	Class: 1
# Generated answer in 0.636 seconds
#
# Sentence:	paei xarilaou kai klaigetai giayta pou ekane o arhs dld ta
# 	idia me ayta pou eginan sthn toumpa
# gpt-4:	Class: 1
# Generated answer in 0.966 seconds
#
# Sentence:	kai kanoun kai dhlwseis tou tupou eytyxws den 8a sas
# 	3anadoume kai tetoia..poioi..........???
# gpt-4:	Class: 1
# Generated answer in 0.540 seconds
#
# Sentence:	milame gia mia omada pou alliws legetai larissa + 1
# gpt-4:	Class: 1
# Generated answer in 0.677 seconds
#
# Sentence:	epeidh pane na dei3oun oti exoun ta kozia kai se aythn thn
# 	xwr se 8emata tetoia enas kanei koumanto
# gpt-4:	Class: 1
# Generated answer in 0.495 seconds
#
# Sentence:	tsekare ti exei na pa8ei o mpaok sto karaiskakh..
# gpt-4:	Class: 1
# Generated answer in 1.429 seconds
#
# Sentence:	h rizoupolh sou leei kati..??
# gpt-4:	Class: 1
# Generated answer in 0.622 seconds
#
# Sentence:	tsampoukades ston olympiako den kaneis..kai otan
# 	kaneis..timwrhse…
# gpt-4:	Class: 0
# Generated answer in 0.655 seconds
#
# Sentence:	Zhtw sugnwmh ek twn proterwn gia tous latinikous xarakthres
# 	(menw ekswteriko...).
# gpt-4:	Class: 1
# Generated answer in 0.584 seconds
#
# Sentence:	Den me peirazei an den dhmosieutei to sxolio mou, elpizw
# 	mono na dw8ei h eukairia ston Mano na to diavasei.
# gpt-4:	Class: 1
# Generated answer in 0.505 seconds
#
# Sentence:	Einai h deuterh fora pou grafw sto gazzetta (thn prwth
# 	ston...Skounth pou agkikse kapoies xordes mou, opws sunh8izei
# 	allote...).
# gpt-4:	Class: 1
# Generated answer in 0.566 seconds
#
# Sentence:	8elw aplws na pw ena euxaristw gia to blogg sou pou me/mas
# 	krathse suntrofia auta ta xronia.
# gpt-4:	Class: 1
# Generated answer in 1.299 seconds
#
# Sentence:	Euxaristw loipon pou mas gemises me uyeieis problhmatismous,
# 	pou mas ekanes na gelasoume (allote pikroxola kai allote apo xara),
# 	ma propantwn 8elw na se euxaristhsw giati eisai TIMIOS kai
# 	alh8inos...
# gpt-4:	Class: 1
# Generated answer in 0.750 seconds
#
# Sentence:	Aksies pou pane va xa8oune pantelws sthn agaphmenh mou
# 	patrida.
# gpt-4:	Class: 1
# Generated answer in 0.570 seconds
#
# Sentence:	Oloi eimaste sthn idia barka, den uparxoun asproi, mauroi,
# 	kokkinoi, kitrinoi eite milame gia to xrwma tou dermatos, eite
# 	opadika, eite politika...
# gpt-4:	Class: 1
# Generated answer in 0.889 seconds
#
# Sentence:	Uparxoun autoi pou kerdizoun apo mia katastash kai autoi pou
# 	xanoun.
# gpt-4:	Class: 1
# Generated answer in 0.502 seconds
#
# Sentence:	Euxaristw polu gia thn gnwrimia kai 8a se brw allou...
# gpt-4:	Class: 1
# Generated answer in 0.653 seconds
#
# Sentence:	OTI NANAI...
# gpt-4:	Class: 1
# Generated answer in 0.961 seconds
#
# Sentence:	AS ERUEI NA DEI  O RVSSOA PVS EINAI TOY XARILAOY
# gpt-4:	Class: 1
# Generated answer in 0.532 seconds
#
# Sentence:	BRAVO x 1000…
# gpt-4:	Class: 1
# Generated answer in 0.536 seconds
#
# Sentence:	MAKARI KAI ALLOI....SAN TON APOLLWNA...!
# gpt-4:	Class: 1
# Generated answer in 0.504 seconds
#
# Sentence:	paidia ta highlights einai edw :
# 	http://www.youtube.com/watch?v=PZsejOMzwbs
# gpt-4:	Class: 1
# Generated answer in 0.580 seconds
#
# Sentence:	Tsalt, telika thn mparoufa thn egrapses pali.
# gpt-4:	Class: 1
# Generated answer in 0.551 seconds
#
# Sentence:	Tria 100arika eriksa kai mallon prepei na ta klaiw.
# gpt-4:	Class: 1
# Generated answer in 0.491 seconds
#
# Sentence:	Kserw omws ti dwro tha parw ston kolito mou to kosta pou
# 	einai skolix sto london.
# gpt-4:	Class: 1
# Generated answer in 0.685 seconds
#
# Sentence:	Tha tou paw ena sxoini se periptwsh pou xalasei to ansanser
# 	na mporesei na anevei.
# gpt-4:	Class: 1
# Generated answer in 0.510 seconds
#
# Sentence:	Esy pote tha kaneis aytokriikh??
# gpt-4:	Class: 1
# Generated answer in 0.621 seconds
#
# Sentence:	To oti apo thn mia lypamai to lew eilikrina giati ola ta
# 	arthra sou prosferoun gelio.
# gpt-4:	Class: 1
# Generated answer in 0.472 seconds
#
# Sentence:	Mporeis na pareis metagrafh ston ARKAS  kai ma sunexiseis na
# 	mas gemizeis me aythono gelio.
# gpt-4:	Class: 1
# Generated answer in 0.970 seconds
#
# Sentence:	Y.S. egw ekana autokritikh.
# gpt-4:	Class: 1
# Generated answer in 0.525 seconds
#
# Sentence:	Twra doulevw 56 wres thn vdomada na refarw.
# gpt-4:	Class: 1
# Generated answer in 0.835 seconds
#
# Sentence:	EKEI EKEI........
# gpt-4:	Class: 1
# Generated answer in 0.578 seconds
#
# Sentence:	Xavier gia panta edo!!!!
# gpt-4:	Class: 1
# Generated answer in 0.556 seconds
#
# Sentence:	eisai toso ka8aros oso kai to elliniki prota8lima!!!
# gpt-4:	Class: 0
# Generated answer in 0.925 seconds
#
# Sentence:	didakse kai esy h8os
# gpt-4:	Class: 1
# Generated answer in 0.556 seconds
#
# Sentence:	Proedre kratise ton oso perissotero ginetai!!!
# gpt-4:	Class: 1
# Generated answer in 0.538 seconds
#
# Sentence:	Pame!!!!
# gpt-4:	Class: 1
# Generated answer in 0.599 seconds
#
# Sentence:	kalispera aek kai kai se olous to allous filathlous tha
# 	ithela na mou pi kapios h katikh exoterikou mporounai na simetexounai
# 	kai afti ??
# gpt-4:	Class: 1
# Generated answer in 0.474 seconds
#
# Sentence:	ean nai pos kai me pion tropo ???... efxaristo....
# gpt-4:	Class: 1
# Generated answer in 0.584 seconds
#
# Sentence:	Proedre mporeis na ton kratiseis gia polla xronia!!!
# gpt-4:	Class: 1
# Generated answer in 0.497 seconds
#
# Sentence:	CRONALDO 13.. ti einai auta p les??
# gpt-4:	Class: 1
# Generated answer in 0.588 seconds
#
# Sentence:	3ereis oti h atletico me thn real einai aiwnioi antipaloi??
# gpt-4:	Class: 1
# Generated answer in 0.576 seconds
#
# Sentence:	kai oi duo omades vriskontai sthn madrith..
# gpt-4:	Class: 1
# Generated answer in 0.596 seconds
#
# Sentence:	olympiakos panathinaikos ena pragma..
# gpt-4:	Class: 1
# Generated answer in 0.476 seconds
#
# Sentence:	einai san na les oti h aek einai pararthma tou
# 	olympiakou..ti allo tha doume?
# gpt-4:	Class: 1
# Generated answer in 0.654 seconds
#
# Sentence:	Makari na ta kataferei omos…
# gpt-4:	Class: 1
# Generated answer in 0.604 seconds
#
# Sentence:	Mazeyeste kai vlepete film etsi? Ela pes tin alitheia....
# gpt-4:	Class: 1
# Generated answer in 0.700 seconds
#
# Sentence:	Efxwme apo ta bathei tis kardias mou na geinei oratw afto to
# 	omorfw plano.
# gpt-4:	Class: 1
# Generated answer in 0.708 seconds
#
# Sentence:	Ala egw nomeizw oti tha geinei to eidio me Panathinaiko.
# gpt-4:	Class: 1
# Generated answer in 0.705 seconds
#
# Sentence:	AXXAXAXXAXAXXXA
# gpt-4:	Class: 1
# Generated answer in 0.530 seconds
#
# Sentence:	Omadara!!!!
# gpt-4:	Class: 0
# Generated answer in 0.545 seconds
#
# Sentence:	KATV H XOYNTA
# gpt-4:	Class: 0
# Generated answer in 0.626 seconds
#
# Sentence:	xaxaxaxaxa!! to poli 2 sas vlepw!!!
# gpt-4:	Class: 1
# Generated answer in 1.005 seconds
#
# Sentence:	oxi oti emeis 8a kanoune perisoteres!!!
# gpt-4:	Class: 1
# Generated answer in 0.567 seconds
#
# Sentence:	pame mwrh ellada!
# gpt-4:	Class: 1
# Generated answer in 0.667 seconds
#
# Sentence:	Tromerh douleia....bravo!
# gpt-4:	Class: 1
# Generated answer in 0.537 seconds
#
# Sentence:	Prosopika pistevo pos sto telos tha meinei!!!!
# gpt-4:	Class: 1
# Generated answer in 0.526 seconds
#
# Sentence:	An I united eprepe na valei k 4o gia na perasei tha to evaze
# 	xalara
# gpt-4:	Class: 1
# Generated answer in 0.572 seconds
#
# Sentence:	O Abeid einai i xrysi metriotita, den einai kakos pouthena,
# 	alla den ksexorizei kai se kanenan tomea
# gpt-4:	Class: 1
# Generated answer in 0.507 seconds
#
# Sentence:	(oute amudika, oute dimiourgika, oute skorer, isws ligi
# 	ekseresi ta foul).
# gpt-4:	Class: 1
# Generated answer in 0.493 seconds
#
# Sentence:	Simfwnw oti einai paiktis proponiti ergaleio kai einai
# 	olokliromenos-poludiastatos mesos.
# gpt-4:	Class: 1
# Generated answer in 0.751 seconds
#
# Sentence:	stin ellada poios tha ton doulepsei na anevei epipedo?
# gpt-4:	Class: 1
# Generated answer in 0.789 seconds
#
# Sentence:	To minima tou marinaki ston alafouzo meso platini..
# gpt-4:	Class: 1
# Generated answer in 0.781 seconds
#
# Sentence:	Kai fisika den akouo diaforetiki koubenta.
# gpt-4:	Class: 1
# Generated answer in 1.324 seconds
#
# Sentence:	H Olympiakara tha nikisei kai tha perasei!!!
# gpt-4:	Class: 1
# Generated answer in 0.857 seconds
#
# Sentence:	pelatako exeis faei polles fapes sti zwh sou!!!
# gpt-4:	Class: 0
# Generated answer in 0.831 seconds
#
# Sentence:	megalos podosfairistis o pepe!!
# gpt-4:	Class: 1
# Generated answer in 0.748 seconds
#
# Sentence:	Tsori gia panta sto limani. Eisai monadikos!!!!
# gpt-4:	Class: 1
# Generated answer in 0.608 seconds
#
# Sentence:	YPOMONI GERA KAI SYNTOMA KONTA !!!!
# gpt-4:	Class: 1
# Generated answer in 0.597 seconds
#
# Sentence:	Pame na tous teleiosoume!!!
# gpt-4:	Class: 0
# Generated answer in 0.558 seconds
#
# Sentence:	kalimera se olous eki sthn patrida tha ithela na rotiso sthn
# 	afkisei metoxikou kefaleou mporoun na semetexoun kai afti pou einai
# 	kai menounai sto exwteriko ???
# gpt-4:	Class: 1
# Generated answer in 0.727 seconds
#
# Sentence:	three-le vasta gera!
# gpt-4:	Class: 1
# Generated answer in 0.513 seconds
#
# Sentence:	ola einai ena psema!
# gpt-4:	Class: 1
# Generated answer in 0.544 seconds
#
# Saving results...
# ======Working on rejected dataset======
# Sentence:	as einai diafimistiko spot ths eurobank...!!!!
# gpt-4:	Class: 1
# Generated answer in 1.694 seconds
#
# Sentence:	1 € na epairne o olympiakos gia kathe m@lkia pou lene oi
# 	gauroi tha eferne k ronaldo
# gpt-4:	Class: 0
# Generated answer in 0.710 seconds
#
# Sentence:	poly swstos file!
# gpt-4:	Class: 1
# Generated answer in 0.525 seconds
#
# Sentence:	XAAXAXAXAXAXAXAXAXAXAXAAXAAXAXAXAXAXAXAXAXAXAXAAXAAXAXAXAXAX
# 	AXAXAXAXAXAAXAAXAXAXAXAXAXAXAXAXAXAAXAAXAXAXAXAXAXAXAXAXAXAAXAAXAXAXA
# 	XAXAXAXA
# gpt-4:	Class: 1
# Generated answer in 0.542 seconds
#
# Sentence:	Pios lloris more...De Gea
# gpt-4:	Class: 0
# Generated answer in 0.611 seconds
#
# Sentence:	Den exei Ellhnika o ypologisths mou.Eimai ektos Elladas.
# gpt-4:	Class: 1
# Generated answer in 0.584 seconds
#
# Sentence:	To sxoleio mou einai.
# gpt-4:	Class: 1
# Generated answer in 0.669 seconds
#
# Sentence:	Den tha mathoume pote,den tha ginoume anthropoi pote.
# gpt-4:	Class: 1
# Generated answer in 0.526 seconds
#
# Sentence:	Mou aresan polu ta sxoleia twn gavrwn gia thn zougla ths
# 	Toumpas.
# gpt-4:	Class: 1
# Generated answer in 0.860 seconds
#
# Sentence:	Lousthte ta twra,exete poly plaka.
# gpt-4:	Class: 1
# Generated answer in 0.601 seconds
#
# Sentence:	vomizo oti prepi va  akirosi xava tn bathimologia kai to -3
# 	va perasi eki eive to pio dikeo
# gpt-4:	Class: 1
# Generated answer in 0.916 seconds
#
# Sentence:	gazzetta synexizeis tin idia politiki vlepo parolo pou sas
# 	to anafera toses fores.
# gpt-4:	Class: 0
# Generated answer in 0.708 seconds
#
# Sentence:	i minysi plisiazei kai den zo ellada na tin glitosete eykola
# gpt-4:	Class: 1
# Generated answer in 0.568 seconds
#
# Sentence:	Olo kai kati tha ginei to kalokairaki omws!opoios diaprepsei
# 	sto mudial…
# gpt-4:	Class: 1
# Generated answer in 0.564 seconds
#
# Sentence:	nai perimene na pe3ei o MPAOK floraki 9elete kai champions
# 	league voulgaroi
# gpt-4:	Class: 1
# Generated answer in 0.525 seconds
#
# Sentence:	Na ginei kala o mitrogoal kai na epistrepsei ston 8rulo kai
# 	na pai3ei opws epaize palia
# gpt-4:	Class: 1
# Generated answer in 0.546 seconds
#
# Sentence:	stigmatismena mia zwh thane ta kaoimena.. krima....
# gpt-4:	Class: 1
# Generated answer in 0.982 seconds
#
# Sentence:	APLA GRAFIKOS !!!
# gpt-4:	Class: 1
# Generated answer in 0.623 seconds
#
# Sentence:	EINAI O MONOS DIETITIS STO MPASKET POU EXEIS ASKOLITHEI TOSO
# 	POLY ME THN DIETISIA (ILITHIOTITA GIA TO MPASKET) !!!
# gpt-4:	Class: 0
# Generated answer in 0.593 seconds
#
# Sentence:	sti tripli isobathmia xania psaxna volos poios einai protos?
# gpt-4:	Class: 1
# Generated answer in 0.528 seconds
#
# Sentence:	H aek aresei ston Lazovits.....?
# gpt-4:	Class: 1
# Generated answer in 0.636 seconds
#
# Sentence:	Mprabo Tamh
# gpt-4:	Class: 1
# Generated answer in 0.563 seconds
#
# Sentence:	Oti xtizame 3 xronia tora min pate na to dialisete se mia
# 	nixta.
# gpt-4:	Class: 1
# Generated answer in 0.678 seconds
#
# Sentence:	Re ARXIGE min ta paratas epidi kapoioi pou theloun na
# 	legonte kai gauroi sou lene pos dn kanis kala ti doulia sou.
# gpt-4:	Class: 0
# Generated answer in 0.535 seconds
#
# Sentence:	Mine ,parta ola kai klistous to stoma. I aksia sou ine
# 	ANAMFISVITITI apo olous tous pragmatikous GAYROUS.
# gpt-4:	Class: 0
# Generated answer in 1.525 seconds
#
# Sentence:	Elpizw na paris ti sosti apofasi kai na ksereis pws gia mas
# 	tha ise o KALITEROS pextis stin europi.
# gpt-4:	Class: 1
# Generated answer in 0.509 seconds
#
# Sentence:	BILLY ALANI GIA PANTA STO LIMANI
# gpt-4:	Class: 1
# Generated answer in 0.500 seconds
#
# Sentence:	O pio proklitikos paixtis tou prwtathlimatos o
# 	Katsouranis...........me diafora!!!!!!!!!!!!!
# gpt-4:	Class: 1
# Generated answer in 0.570 seconds
#
# Sentence:	den poulaei .. option out (lynei to symvolaio= tous afinei
# 	ELEUTHEROUS
# gpt-4:	Class: 1
# Generated answer in 0.572 seconds
#
# Sentence:	Mia San mia !!!!
# gpt-4:	Class: 1
# Generated answer in 0.580 seconds
#
# Sentence:	opu pai o Murinjo katastrafi to podhosfero.Aftos ine ena
# 	karagjosi tipota alo.
# gpt-4:	Class: 0
# Generated answer in 0.505 seconds
#
# Sentence:	mono pou se auth th periptwsh o perperoglou de ton vriskei
# 	katholou…
# gpt-4:	Class: 1
# Generated answer in 0.583 seconds
#
# Sentence:	alla mallon sou ksefuge.....
# gpt-4:	Class: 1
# Generated answer in 0.592 seconds
#
# Sentence:	enw o matsioulis vriskei ton spanouli sto oaka pentakathara
# 	alla ekei den to eidan!!
# gpt-4:	Class: 1
# Generated answer in 0.648 seconds
#
# Sentence:	k se periptwsh pou psaxneis na apanthseis....des prwta ta
# 	video!
# gpt-4:	Class: 1
# Generated answer in 0.515 seconds
#
# Sentence:	OXIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII
# 	IIIIIIIIIIIII
# gpt-4:	Class: 1
# Generated answer in 0.711 seconds
#
# Sentence:	axaxaxaxaxaxa o stefanos
# gpt-4:	Class: 1
# Generated answer in 0.588 seconds
#
# Sentence:	O olumpiakos prepei na pairnei ta panta sthn ellada gt einai
# 	h kaluterh omada pantou s ola ta athlimata kai exei tous kaluterous
# 	opadous pou didaskoun ithos.
# gpt-4:	Class: 1
# Generated answer in 0.838 seconds
#
# Sentence:	na afairethoun t vraveia apo ton berg ton anastasiou kai ton
# 	risvani na t dwsoun ston mitroglou p einai sthn agglia ston mitsel
# 	pou phre prwtathlima apo ton augousto p perase kai gia kalutero neo
# 	paixth na to dwsoun ston vergo.
# gpt-4:	Class: 1
# Generated answer in 0.649 seconds
#
# Sentence:	MPEEEEEEEEEEEEEEEEEEEEEEEEE
# gpt-4:	Class: 0
# Generated answer in 0.481 seconds
#
# Sentence:	Ase twra re Gazzeta pou einai kata tou ratsismou kai
# 	malakies..
# gpt-4:	Class: 0
# Generated answer in 0.499 seconds
#
# Sentence:	Na prostatepsoun tin epeixirisi tous theloun kai einai apla
# 	toso epaggelmaties pou den afinoun xwro gia disfimiseis ktlp.
# gpt-4:	Class: 1
# Generated answer in 0.598 seconds
#
# Sentence:	pedia signomi kai diorthosteme ean kano lathos ean i omada
# 	pari kalathi ,zisi , bougiouka ,ena kalo 3ari , kai kratisi bramo
# 	masiouli gist lasme diamantidi toy pitsirikades pou ihame fetos fotsi
# 	kai pari 1-2 elinas akomaopos athineou i ton mpohoridi i ton cuper
# 	den tha ehoume kali omada osos gia coach na mini to team kai aplos na
# 	ine + ean erthi o bosnios ohi omos monos toy diafonite ?
# gpt-4:	Class: 1
# Generated answer in 0.576 seconds
#
# Sentence:	siga mhn einai kai kitrino to aigio einai aspromauro
# gpt-4:	Class: 1
# Generated answer in 0.560 seconds
#
# Sentence:	bravo niki
# gpt-4:	Class: 1
# Generated answer in 0.679 seconds
#
# Sentence:	eyxaristo neo giati einai enas apo tous elaxistous germanous
# 	pou einai agapitos ston kosmo
# gpt-4:	Class: 1
# Generated answer in 0.704 seconds
#
# Sentence:	trelenomai
# gpt-4:	Class: 1
# Generated answer in 0.508 seconds
#
# Sentence:	xaxaxaxaxaxaxa!!!!!!!!!!!!!
# gpt-4:	Class: 1
# Generated answer in 0.597 seconds
#
# Sentence:	PANATHINAIKOS…
# gpt-4:	Class: 1
# Generated answer in 0.595 seconds
#
# Sentence:	kala nomizete oti exoume kalyteres ypodomes.
# gpt-4:	Class: 1
# Generated answer in 0.636 seconds
#
# Sentence:	ta topika einai ola xera kai giafto den paei kanena paidaki
# 	na spasi ta podia tou
# gpt-4:	Class: 1
# Generated answer in 0.554 seconds
#
# Sentence:	Re file Athanasie na sovareftoume ligo... o maduca den tha
# 	paei apo ta salonia sta alonia.
# gpt-4:	Class: 1
# Generated answer in 0.528 seconds
#
# Sentence:	Milame gia ena APOEL pou eftase stous 8 tou CH LEAGE me ton
# 	MADUCA ,episis fetos epexe omilous Europa Leage me ton MADUCA...me ti
# 	kinitro na erthi na pexi ston PANETOLIKO..
# gpt-4:	Class: 1
# Generated answer in 1.554 seconds
#
# Sentence:	To APOEL mpori aneta na xtipisi se ena protathlima
# 	opiadipote omada Super Leage Ektos tou OSFP…
# gpt-4:	Class: 1
# Generated answer in 1.043 seconds
#
# Sentence:	min Ipotimate To APOEL giati i istoria einai ekei kai einai
# 	grameni...evxaristo…
# gpt-4:	Class: 1
# Generated answer in 0.970 seconds
#
# Sentence:	episis lefta iparxoun kai o kosmos tou APOEL tima kai
# 	akolouthi tin omada pantou opos mono aftos xerei...
# gpt-4:	Class: 1
# Generated answer in 0.627 seconds
#
# Sentence:	kai an theleis kai apodixeis
# 	oriste...https://www.youtube.com/watch?v=E6GBh8_LCy8 ama deis afto to
# 	video tha katalaveis ti simenei APOEL kai an mpori mia omada tou
# 	velinekous tou PANETOLIKOU na parei pexti apo to APOEL xoris na einai
# 	epilogi tou APOEL
# gpt-4:	Class: 1
# Generated answer in 0.644 seconds
#
# Sentence:	Mathame apo esas pou ta kanete tosa xronia
# gpt-4:	Class: 1
# Generated answer in 0.638 seconds
#
# Sentence:	Oi dimosiografoi kanoun erevna , reportaz dn sxoliazoun mono
# 	ta apotelesmata twn agonwn.
# gpt-4:	Class: 1
# Generated answer in 0.555 seconds
#
# Sentence:	Gia pes mas ti egine telika me to thema tou Batiste otan ton
# 	sinellavan perisi sto aerodromio gia forodiafigi??
# gpt-4:	Class: 1
# Generated answer in 0.819 seconds
#
# Sentence:	Ekanes mipws esi i kapoios allos antikeimenikos ektenes
# 	reportaz???
# gpt-4:	Class: 1
# Generated answer in 0.475 seconds
#
# Sentence:	Ti reportaz ekanes gia tin afksisi metoxikou kefalaiou
# 	300.000 evro tou D.Giannakopoulou tin wra pou o pao eixe budget 10
# 	ekatomiria.
# gpt-4:	Class: 1
# Generated answer in 0.746 seconds
#
# Sentence:	Ti exeis na peis gia ti diafaneia tis ked tin wra pou i
# 	klirwsi tha einai kleisti apo ta mme 2 wres prin ton teliko??
# gpt-4:	Class: 1
# Generated answer in 0.602 seconds
#
# Sentence:	Me poia kritiria epilexthikan oi 5 diaitites??
# gpt-4:	Class: 1
# Generated answer in 0.570 seconds
#
# Sentence:	Thewreis simptwsi oti dn einai kanenas stin klirwsi apo tous
# 	3 pou sfiriksan ston trito teliko k tous epitethike meta o
# 	Giannakopoulos??
# gpt-4:	Class: 1
# Generated answer in 0.617 seconds
#
# Sentence:	Thewreis oti einai swsto na sfirizoun diaitites pou dn
# 	pliroun ta kritiria tis fiba??
# gpt-4:	Class: 1
# Generated answer in 0.471 seconds
#
# Sentence:	Giati o Vasilakopoulos dn parousiazei ta asfalistra twn
# 	paiktws afou ipostirizei oti einai asfalismenoi?
# gpt-4:	Class: 1
# Generated answer in 0.584 seconds
#
# Sentence:	Poios itan o mistirios xrimatodotis pou edwse ta lefta gia
# 	ti wild card??
# gpt-4:	Class: 1
# Generated answer in 0.857 seconds
#
# Sentence:	Episis thewreis se kairo krisis swsto o kirios
# 	Vasilakopoulos na dinei tetoia posa gia wild card otan o kosmos
# 	peinaei?
# gpt-4:	Class: 1
# Generated answer in 0.676 seconds
#
# Sentence:	Apo ti stigmi epomenws pou vriskei xrimata gia wild card ,
# 	na vrei k gia asfalistra.
# gpt-4:	Class: 1
# Generated answer in 0.823 seconds
#
# Sentence:	An thete na legeste dimosiografos sas parakalw na grapsete
# 	ena arthro pou tha dinete apantiseis gia ola afta.
# gpt-4:	Class: 1
# Generated answer in 0.901 seconds
#
# Sentence:	to gipedo tis aek to eidane? :P
# gpt-4:	Class: 1
# Generated answer in 0.491 seconds
#
# Sentence:	megalos paikths terastia psixh!
# gpt-4:	Class: 1
# Generated answer in 0.891 seconds
#
# Sentence:	apla sevasmos kai eugnwmosunh ston 3D!!
# gpt-4:	Class: 1
# Generated answer in 0.550 seconds
#
# Sentence:	ronaldinho kai drogba giati ektos apostolis traumaties i
# 	timwrimenoi.?????
# gpt-4:	Class: 1
# Generated answer in 0.621 seconds
#
# Sentence:	mpeeeeeeeeeeeeeeeee
# gpt-4:	Class: 1
# Generated answer in 0.471 seconds
#
# Sentence:	penalti iper tou torosidi,den 8odikie
# gpt-4:	Class: 1
# Generated answer in 0.543 seconds
#
# Sentence:	AMA DEN DVUOYN TA SYMBOLAIA(OPVS PREPEI)KANEIS STHN EUNIKH
# 	(KAI OPOYDHPOTE ALLOY)
# gpt-4:	Class: 1
# Generated answer in 0.714 seconds
#
# Sentence:	Pesta anthrwpe m..olo mikroprepies..t xronu tha prepei na
# 	valei 25 goals gia na min ine looser...gia panta real..hala madrid!!
# gpt-4:	Class: 0
# Generated answer in 0.534 seconds
#
# Sentence:	apla kourastikoi...!!!
# gpt-4:	Class: 1
# Generated answer in 0.934 seconds
#
# Sentence:	metaksu mas twra, opote xanei o pao einai ka8aro match,
# 	opote nikaei o pao einai sthmenoi oi diaithtes…
# gpt-4:	Class: 1
# Generated answer in 0.494 seconds
#
# Sentence:	re vlepoun fantasmata gt exoun thn muga me auta p kanoun
# 	sthn mpala kai mugiazontai xDDDDDDDD...
# gpt-4:	Class: 1
# Generated answer in 0.583 seconds
#
# Sentence:	nai mono ena recor espase me tin real re ta perrisotera goal
# 	se mia season …
# gpt-4:	Class: 1
# Generated answer in 0.504 seconds
#
# Sentence:	ola stin antepi8esh itan apo oti 8ymamai
# gpt-4:	Class: 1
# Generated answer in 0.555 seconds
#
# Sentence:	Symfwnw me ton dhmosiografo....fanhke allwste poso duskolo
# 	htan k perysi sto 3-0 twn telikwn...:-)
# gpt-4:	Class: 1
# Generated answer in 0.489 seconds
#
# Sentence:	MORALIS DOUROU KAI GAYROS STI FILADELFEIA.GIPEDO E NA
# gpt-4:	Class: 1
# Generated answer in 0.472 seconds
#
# Sentence:	max aek pou les oti de vgazoume paiktes,o mirallas,o toure,o
# 	mitrogloy,o castillo,o kyriakos papadopoylos kai alloi polloi soy
# 	thymizoun tipota.
# gpt-4:	Class: 1
# Generated answer in 0.537 seconds
#
# Sentence:	ma ti lew mono na lete oti sas katevei sto kefali kserete!!
# gpt-4:	Class: 0
# Generated answer in 0.500 seconds
#
# Sentence:	gia na to doume to allani to keno mpogiobits an kalucei
# gpt-4:	Class: 1
# Generated answer in 0.562 seconds
#
# Sentence:	i celtic den paizei CL ?
# gpt-4:	Class: 1
# Generated answer in 0.829 seconds
#
# Sentence:	ti einai auta pou grafete ?
# gpt-4:	Class: 1
# Generated answer in 0.527 seconds
#
# Sentence:	Cheno, de nomizw na eisai toso ellhnas me ayto to
# 	nickname/epitheto, opote mallon eisai pros to exw psixologika/wonna
# 	be ellhnas
# gpt-4:	Class: 0
# Generated answer in 0.599 seconds
#
# Sentence:	YPOVRILOS RESPECT!!!
# gpt-4:	Class: 1
# Generated answer in 0.588 seconds
#
# Sentence:	gia kamia totenam kai to poli gia kamia roma einai autos
# gpt-4:	Class: 1
# Generated answer in 0.585 seconds
#
# Sentence:	ti den katalavainete...?
# gpt-4:	Class: 1
# Generated answer in 0.479 seconds
#
# Sentence:	Pali kala exoume ote
# gpt-4:	Class: 1
# Generated answer in 0.525 seconds
#
# Sentence:	RIXNEI PARAGADI GIA NA PSAREPSEI KANALI THS
# 	THLEORASHS..EINAI H EPOXH BLEPEIS POY RIXNOYN TA PARAGADIA TORA…
# gpt-4:	Class: 1
# Generated answer in 1.145 seconds
#
# Sentence:	salpi tipota den aksizei auth h xwra me aytoys tous
# 	polites..paikste gia thn parth sas kai gi autous pou sas sthrizoun
# 	kai sas pisteuoun!
# gpt-4:	Class: 1
# Generated answer in 0.512 seconds
#
# Sentence:	se kathe filiko pou paizei h ellada kai se kathe diorganwsh
# 	akouw pollous pou uposthrizoun tis ksenes xwres pou paizoun antipales
# 	mas..tetoia nootropia anthelliniki den exw ksanadei pouthena!
# gpt-4:	Class: 0
# Generated answer in 0.560 seconds
#
# Sentence:	einai 25!
# gpt-4:	Class: 1
# Generated answer in 0.604 seconds
#
# Sentence:	oxi 28
# gpt-4:	Class: 1
# Generated answer in 0.929 seconds
#
# Sentence:	kalispera kriti ime gia des protoselido oras giati ego osa
# 	hanumia xero grami ihan pari mipos ekane ki i original sigentrosi?
# gpt-4:	Class: 1
# Generated answer in 0.743 seconds
#
# Sentence:	leo tora ego
# gpt-4:	Class: 1
# Generated answer in 0.532 seconds
#
# Sentence:	XXAXAXXAXAXAXAXAXAXA
# gpt-4:	Class: 1
# Generated answer in 0.535 seconds
#
# Sentence:	Re paidia pianei ti mpala kai tin petaei sto terma apo ta
# 	neura kai ti xara pou epitelous meta apo toso wra epithesi mpike goal
# 	sto telutaio lepto!
# gpt-4:	Class: 1
# Generated answer in 0.502 seconds
#
# Sentence:	opoios eide mats eide kai tin efrasi tou!
# gpt-4:	Class: 1
# Generated answer in 0.577 seconds
#
# Sentence:	Twra apo ton panigyrismo apo mia kamera sto tavani bgazete
# 	simperasmata!
# gpt-4:	Class: 1
# Generated answer in 0.771 seconds
#
# Sentence:	den etrekse sti gwnia gt poly apla oloi itan ekei kai
# 	gurnouse pisw!
# gpt-4:	Class: 1
# Generated answer in 0.541 seconds
#
# Sentence:	prepei se ola na ton katadikasoume??
# gpt-4:	Class: 1
# Generated answer in 0.491 seconds
#
# Sentence:	poios zekaa pisteueis exei asxolhthei o olimpiakos mazi
# 	tou...
# gpt-4:	Class: 1
# Generated answer in 0.637 seconds
#
# Sentence:	GELAEI O KOSMOS ME AUTA POU LETE MERIKOI,pele sigoura den
# 	tha rthei ston olimpiako me tosa gkol kai tetoia xronia pou exei
# 	kanei apla akougetai to onoma tou paixnidia twn manager kai twn
# 	dhmosiografwn na gemhsoun tis filades tous ]
# gpt-4:	Class: 1
# Generated answer in 0.553 seconds
#
# Sentence:	stokos alert
# gpt-4:	Class: 0
# Generated answer in 0.874 seconds
#
# Sentence:	oti pio kobleksiko exw diavasei pote ston internet!
# gpt-4:	Class: 1
# Generated answer in 1.704 seconds
#
# Saving results...

# %%
results_gpt4
# Out:
# ['Class: 1',
#  'Class: 0',
#  'Class: 1',
#  'Class: 1',
#  'Class: 0',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 0',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 0',
#  'Class: 1',
#  'Class: 0',
#  'Class: 1',
#  '0',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 0',
#  'Class: 0',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 0',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 0',
#  '0',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 0',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 0',
#  'Class: 1',
#  'Class: 0',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  '1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1',
#  'Class: 1']
